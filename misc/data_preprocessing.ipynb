# %%
import json
import pandas as pd
import numpy as np

# %%
# with open("YT-dataset-new/US_category_id.json") as f:
#     categories = json.load(f)["items"]
    
# cat_dict = {}
# for cat in categories:
#     cat_dict[int(cat["id"])] = cat["snippet"]["title"]

# %%
# cat_dict

# %%
df = pd.read_csv('US_youtube_trending_data_sentiment.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151092 entries, 0 to 151091
# Data columns (total 24 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           151092 non-null  int64
#  1   Unnamed: 0.1         151092 non-null  int64
#  2   video_id             151092 non-null  object
#  3   title                151092 non-null  object
#  4   publishedAt          151092 non-null  object
#  5   channelId            151092 non-null  object
#  6   channelTitle         151092 non-null  object
#  7   categoryId           151092 non-null  int64
#  8   trending_date        151092 non-null  object
#  9   tags                 151092 non-null  object
#  10  view_count           151092 non-null  int64
#  11  likes                151092 non-null  int64
#  12  dislikes             151092 non-null  int64
#  13  comment_count        151092 non-null  int64
#  14  thumbnail_link       151092 non-null  object
# ...

# %%
# df['category'] = df['categoryId'].map(cat_dict)

# %%
df['category'].value_counts()
# Out:
# Entertainment            30024
# Gaming                   29828
# Music                    25497
# Sports                   16116
# People & Blogs           12817
# Comedy                    7909
# Film & Animation          6066
# News & Politics           5815
# Science & Technology      4773
# Howto & Style             4428
# Education                 3565
# Autos & Vehicles          2722
# Travel & Events            737
# Pets & Animals             683
# Nonprofits & Activism      112
# Name: category, dtype: int64

# %%
# df.to_csv('US_youtube_trending_data.csv')

# %%
# from datetime import datetime

# def __datetime(date_str):
#     return datetime.strptime(date_str, "%Y-%m-%dT%H:%M:%SZ")

# %%
# df['days_to_trend'] = 0
# for i in range(len(df)):
#     df['days_to_trend'][i] = (__datetime(df['trending_date'][i]) - __datetime(df['publishedAt'][i])).days

# %%
# df['days_to_trend'].value_counts()

# %%
# df.head()

# %%
# df.drop(df[df.days_to_trend == -1].index, inplace = True)

# %%
dfTest = df
dfTest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151092 entries, 0 to 151091
# Data columns (total 22 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           151092 non-null  int64
#  1   video_id             151092 non-null  object
#  2   title                151092 non-null  object
#  3   publishedAt          151092 non-null  object
#  4   channelId            151092 non-null  object
#  5   channelTitle         151092 non-null  object
#  6   categoryId           151092 non-null  int64
#  7   trending_date        151092 non-null  object
#  8   tags                 151092 non-null  object
#  9   view_count           151092 non-null  int64
#  10  likes                151092 non-null  int64
#  11  dislikes             151092 non-null  int64
#  12  comment_count        151092 non-null  int64
#  13  thumbnail_link       151092 non-null  object
#  14  comments_disabled    151092 non-null  bool
# ...

# %%
dfTest.head()
# Out:
#    Unnamed: 0     video_id                                              title  \
# 0           0  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1           1  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2           2  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3           3  kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4           4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
#
#             publishedAt                 channelId   channelTitle  categoryId  \
# 0  2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg       Brawadis          22
# 1  2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A   Apex Legends          20
# 2  2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g  jacksepticeye          24
# 3  2020-08-11T16:38:55Z  UCbg_UMjlHJg_19SZckaKajg            XXL          10
# 4  2020-08-11T15:10:05Z  UCDVPcEbVLQgLZX0Rt6jo34A       Mr. Kate          26
#
# ...

# %%
mean_view = dfTest['view_count'].median()
mean_comment = dfTest['comment_count'].median()
mean_votes = (dfTest['likes'] + dfTest['dislikes']).median()

# %%
print(mean_view, mean_comment, mean_votes)
# Out:
# 1011647.0 3222.0 46660.0

# %%
dfTest['popularity'] = np.where((dfTest['view_count'] > mean_view) & (dfTest['comment_count'] > mean_comment) & ((dfTest['likes'] + dfTest['dislikes']) > mean_votes), True, False)

# %%
dfTest.head()
# Out:
#    Unnamed: 0     video_id                                              title  \
# 0           0  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1           1  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2           2  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3           3  kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4           4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
#
#             publishedAt                 channelId   channelTitle  categoryId  \
# 0  2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg       Brawadis          22
# 1  2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A   Apex Legends          20
# 2  2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g  jacksepticeye          24
# 3  2020-08-11T16:38:55Z  UCbg_UMjlHJg_19SZckaKajg            XXL          10
# 4  2020-08-11T15:10:05Z  UCDVPcEbVLQgLZX0Rt6jo34A       Mr. Kate          26
#
# ...

# %%
dfTest.to_csv('US_youtube_trending_data_popularity.csv', index=False)

# %%
df = pd.read_csv('US_youtube_trending_data_popularity.csv')

# %%
df = df[['publishedAt','Sentiment_Scores']]

# %%
# df['publishedAt'] = df['publishedAt'][:][:10]
df
# Out:
#        publishedAt  Sentiment_Scores
# 0       2020-08-11            0.5371
# 1       2020-08-11            0.8625
# 2       2020-08-11            0.5574
# 3       2020-08-11            0.7003
# 4       2020-08-11            0.7650
# ...            ...               ...
# 151087  2022-09-20            0.7946
# 151088  2022-09-21            0.0516
# 151089  2022-09-20           -0.6808
# 151090  2022-09-19            0.0000
# 151091  2022-09-20            0.8964
#
# [151092 rows x 2 columns]

# %%
for i, row in df.iterrows():
    df.at[i,'publishedAt'] = df[i]
# Out:
# C:\Users\nirma\anaconda3\envs\infoviz\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.to_csv('US_youtube_trending_data_calendar.csv')

# %%
df = pd.read_csv('US_youtube_trending_data_calendar.csv')

# %%
df = df[['publishedAt', 'Sentiment_Scores']]

# %%
df
# Out:
#        publishedAt  Sentiment_Scores
# 0       2020-08-11            0.5371
# 1       2020-08-11            0.8625
# 2       2020-08-11            0.5574
# 3       2020-08-11            0.7003
# 4       2020-08-11            0.7650
# ...            ...               ...
# 151087  2022-09-20            0.7946
# 151088  2022-09-21            0.0516
# 151089  2022-09-20           -0.6808
# 151090  2022-09-19            0.0000
# 151091  2022-09-20            0.8964
#
# [151092 rows x 2 columns]

# %%
df.to_csv('US_youtube_trending_data_calendar.csv', index=False)

# %%
df
# Out:
#        publishedAt  Sentiment_Scores
# 0       2020-08-11            0.5371
# 1       2020-08-11            0.8625
# 2       2020-08-11            0.5574
# 3       2020-08-11            0.7003
# 4       2020-08-11            0.7650
# ...            ...               ...
# 151087  2022-09-20            0.7946
# 151088  2022-09-21            0.0516
# 151089  2022-09-20           -0.6808
# 151090  2022-09-19            0.0000
# 151091  2022-09-20            0.8964
#
# [151092 rows x 2 columns]
